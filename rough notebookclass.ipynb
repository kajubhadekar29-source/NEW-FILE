# %%
print("Hello")
# Out:
# Hello

# %%
print("Hello @#%%^^*&&*   &   !World")
print('He said, Hello to everyone.')
print("My sisters dress is cute")
# Out:
# Hello @#%%^^*&&*   &   !World
# He said, Hello to everyone.
# My sisters dress is cute

# %%
print('Hello, "How are you".')
# Out:
# Hello, "How are you".

# %%
a = 10
b = 5
c = a+b # 10+ 5 = 15 ===> c = 15
print("c") #string
print("adition",c)    #variable
# Out:
# c
# adition 15

# %%
# To directly print the output of expression 
a1 = 10
b1 = 20
print(a1+b1)  #10 +20 = 30 ===> print (30)
# Out:
# 30

# %%
# single Variable
s = "Bob"
print(s)




# Multiple Variables
a = "Amit"
age = 25
city = "indore"

#Printing variables in different ways
print(a, age,city)
print("My Name is",a)
print("My Name is", a, ".I am", age, "years old. I live in",city)
print(f'My Name is {a}. I am {age} years old. I live in {city}')
print("Name= {} age {} city {}". format(a,age,city))
print("My Nmae is "+ a +"city is "+ city)       #known as string concatenation
# Out:
# Bob
# Amit 25 indore
# My Name is Amit
# My Name is Amit .I am 25 years old. I live in indore
# My Name is Amit. I am 25 years old. I live in indore
# Name= Amit age 25 city indore
# My Nmae is Amitcity is indore

# %%
a = 25
b = 75
c = a+b
print(c)
# Out:
# 100

# %%
a = 50
b = 18
c = a-b
print(c)
# Out:
# 32

# %%
a = 15     #two variables
b = 5
c = a+b
print(c)
# Out:
# 20

# %%
#two variables
x = 20
y = 4
z =x/y
print(z)
# Out:
# 5.0

# %%
#p= 2(l+w)
l = 10
w = 6
p = 2*(l+w)
print(p)
# Out:
# 32

# %%
p = 250        #price = p , quantity = q
q = 3
ptc = p*q
print(ptc)
# Out:
# 750

# %%
# square = 12*12 , 
s = 12*12
print(s)
# Out:
# 144

# %%
#hello; This is comments for your understanding 
#make it eassy
#did you understand what i trying to understand you.
#this are multi-line comments 
#bye.
print("Hello")
# Out:
# Hello

# %%
a = "KAJAL"
b = "PHANSE"
h = "Sudoku"
w = 45 
s = "I have one eldest brother, his name is Manoj."

#a = Name,b = surname,h = hobby,w= weight, s= sibling
print("I am",a,b,"my hobby is playing",h,"my Weight is")
# Out:
# I am KAJAL PHANSE my hobby is playing Sudoku my Weight is

# %%
a = (2+3*4)
b = ((2+3)*4)
c = a + b
print(c)
# Out:
# 34

# %%
print("Hello! My name is 'Kajal Phanse'.")
print("I am learning python to build my skills")
print("I did UG in BBA and PG in MBA ")
print("I did schooling from City convent higher secondary school sudama nagar")
print("I have 1years experience in CA firm as a junior accountant assistant ")
print("My hobby are reading book and playing sudoku")
print("I live in indore")
print("In my family we are 5 members my husband and my father and mother in law and grandmother in law ")
print("I have One pet his name is simba")
print("I love travelling and i recently visited Andaman Nicobar, Kashmir , Rajasthan and Bali.")
# Out:
# Hello! My name is 'Kajal Phanse'.
# I am learning python to build my skills
# I did UG in BBA and PG in MBA
# I did schooling from City convent higher secondary school sudama nagar
# I have 1years experience in CA firm as a junior accountant assistant
# My hobby are reading book and playing sudoku
# I live in indore
# In my family we are 5 members my husband and my father and mother in law and grandmother in law
# I have One pet his name is simba
# I love travelling and i recently visited Andaman Nicobar, Kashmir , Rajasthan and Bali.

# %%
# %history -f main1.py
